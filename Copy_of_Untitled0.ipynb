# %% [markdown]
# <a href="https://colab.research.google.com/github/AfraazUlHaque/practice/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google playstore Data

# %%
#Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/drive/MyDrive/CNB/googleplaystore.csv')

# %% [markdown]
# ## Remove row with '1,000+' in 'Size' column

# %%
df = df[df['Size'] != '1,000+']
display(df.head())

# %%
df.head()

# %%
#IMP THINGS
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#hide all warning
import warnings
warnings.filterwarnings('ignore')

# %%
print(f"no of rows: {df.shape[0]}")
print(f"no of columns: {df.shape[1]}")

# %%
df['Size'].unique()

# %% [markdown]
# ---
# ## OBSERVATIONS
# "VARY WITH DEVICE" ,
# M ,
# K
# ---

# %%
df.info()

# %% [markdown]
#  **No missing values in size**

# %%
#No of values having M in them :
df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()

# %%
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()

# %%
df['Size'].loc[df['Size'].str.contains('Varies with device')].value_counts().sum()

# %%
#lets define a fn to covert the size  Bytes !
def convert_size(size):
  if isinstance(size, str):
    if 'k' in size:
        return float(size.replace('k', '')) *1024
    elif 'M' in size:
        return float(size.replace('M', '')) *1024*1024
    elif 'Varies with device' in size:
        return np.nan
    else:
        return float(size)

# %%
df['Size'] = df['Size'].apply(convert_size)

# %%
df.head()

# %%
df['size'] = df['size_mb'].apply(lambda x: x/(1024*1024) )

# %%
df.head()

# %%
#making install col numeric:
df['Installs'] = df['Installs'].apply(lambda x: x.replace('+' , "") if '+' in str(x) else x)
df['Installs'] = df['Installs'].apply(lambda x: x.replace(',' , "") if ',' in str(x) else x)
df['Installs'] = df['Installs'].apply(lambda x: int(x))

# %%
df['Installs'].value_counts()

# %% [markdown]
# # Task
# Find the unique value in the 'Size' column that does not contain 'k', 'M', or 'Varies with device', and confirm it.

# %% [markdown]
# ## Find unique size value
#
# ### Subtask:
# Filter the 'Size' column to identify and display the unique value that does not contain 'k', 'M', or 'Varies with device'.

# %% [markdown]
# **Reasoning**:
# I will filter the 'Size' column to exclude values containing 'k', then 'M', then 'Varies with device' to find the unique remaining value, as per the instructions.

# %%
filtered_size = df[df['Size'].str.contains('k') == False]
filtered_size = filtered_size[filtered_size['Size'].str.contains('M') == False]
filtered_size = filtered_size[filtered_size['Size'].str.contains('Varies with device') == False]
unique_value = filtered_size['Size'].unique()
print(unique_value)

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm the identified unique value from the 'Size' column.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The unique value in the 'Size' column that does not contain 'k', 'M', or 'Varies with device' is '1,000+'.
#
# ### Data Analysis Key Findings
# *   The 'Size' column was filtered to exclude entries containing 'k', 'M', or 'Varies with device'.
# *   After applying these filters, the only unique value remaining in the 'Size' column was '1,000+'.
#
# ### Insights or Next Steps
# *   This identified unique value '1,000+' might represent a count rather than a specific size, suggesting a need for a separate handling strategy if the 'Size' column is intended to contain only quantitative size measurements.
# *   Consider standardizing this value or converting it into a numerical format, if possible, to enable further quantitative analysis on the 'Size' column.
