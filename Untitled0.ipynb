# %% [markdown]
# <a href="https://colab.research.google.com/github/AfraazUlHaque/practice/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
data1 = {'id' : [1,2,3],
         'naam' : ['Afraz' , 'ziya' , 'faizan']}
df1 = pd.DataFrame(data1)
df1
# Out:
#    id    naam
# 0   1   Afraz
# 1   2    ziya
# 2   3  faizan

# %%
data2 = {'id' : [1,2,4],
         'name' : ['naira' , 'ariyan' , 'afifa']}
df2 = pd.DataFrame(data2)
df2
#
# Out:
#    id    name
# 0   1   naira
# 1   2  ariyan
# 2   4   afifa

# %%
merge_df = pd.merge(df1,df2, on='id' , how = 'outer')
merge_df
# Out:
#    id    naam    name
# 0   1   Afraz   naira
# 1   2    ziya  ariyan
# 2   3  faizan     NaN
# 3   4     NaN   afifa

# %%
merge_df = pd.merge(df1,df2, on='id' , how = 'inner')
merge_df
# Out:
#    id   naam    name
# 0   1  Afraz   naira
# 1   2   ziya  ariyan

# %%
tpd.concat([df1,df2])
#
# Out:
#    id    naam    name
# 0   1   Afraz     NaN
# 1   2    ziya     NaN
# 2   3  faizan     NaN
# 0   1     NaN   naira
# 1   2     NaN  ariyan
# 2   4     NaN   afifa
